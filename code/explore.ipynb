# %% [markdown]
# # Bill Splitter — Notebook
#
# This notebook is the **notebook interface** for the Bill Splitter. Like the
# console and Streamlit apps, it does no math of its own — it imports `bill.py`
# and calls its functions to explore different tips.
#
# Run each cell with **Shift+Enter** (choose the `/usr/local/bin/python` kernel the
# first time), or use **Run All**.

# %%
import importlib
import pandas as pd

import bill
importlib.reload(bill)
# Out:
# <module 'bill' from '/workspace/code/bill.py'>

# %%
# One example: a $50 bill, a 20% tip, split 4 ways.
subtotal, pct, people = 50.0, 20, 4
total = bill.grand_total(subtotal, pct)
per_person = bill.split_evenly(total, people)

print(f"Grand total: ${total:.2f}")
print(f"Each of {people} pays: ${per_person:.2f}")
per_person
# Out:
# Grand total: $60.00
# Each of 4 pays: $15.00
# 15.0

# %%
# Compare the per-person cost across a range of tip percentages.
percents = [10, 15, 18, 20, 25]
table = pd.DataFrame(
    {"per person": [bill.split_evenly(bill.grand_total(subtotal, p), people) for p in percents]},
    index=[f"{p}%" for p in percents],
)
table
# Out:
#     per person
# 10%       None
# 15%       None
# 18%       None
# 20%       None
# 25%       None

# %%
# A quick bar chart of the same data.
table.plot(kind="bar", legend=False, title="Per-person cost by tip %")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 # A quick bar chart of the same data.
# ----> 2 table.plot(kind="bar", legend=False, title="Per-person cost by tip %")
#
# File /usr/local/lib/python3.13/site-packages/pandas/plotting/_core.py:1185, in PlotAccessor.__call__(self, *args, **kwargs)
#    1182             label_name = label_kw or data.columns
#    1183             data.columns = label_name
# -> 1185 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /usr/local/lib/python3.13/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plt.draw_if_interactive()
#      73 return plot_obj.result
#
# File /usr/local/lib/python3.13/site-packages/pandas/plotting/_matplotlib/core.py:516, in MPLPlot.generate(self)
#     514 @final
#     515 def generate(self) -> None:
# --> 516     self._compute_plot_data()
#     517     fig = self.fig
#     518     self._make_plot(fig)
#
# File /usr/local/lib/python3.13/site-packages/pandas/plotting/_matplotlib/core.py:716, in MPLPlot._compute_plot_data(self)
#     714 # no non-numeric frames or series allowed
#     715 if is_empty:
# --> 716     raise TypeError("no numeric data to plot")
#     718 self.data = numeric_data.apply(type(self)._convert_to_ndarray)
#
# TypeError: no numeric data to plot
